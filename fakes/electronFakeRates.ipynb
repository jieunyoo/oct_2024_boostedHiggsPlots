# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mplhep as hep
xErrorWidth = [20,10,10,10,10,10,10,10,10,50,70,50,100]

# %%
fig, ax = plt.subplots()

a = [40,55,65,75,85,95,105,115,125,155,215,275,350]
b = [.407,.420,.466,.502,.542,.435,.455,.366,.091,.091,.100,.054,.046]
 
c = [0.029,.032,.029,.032,.032,.033,.053,.033,.030,.002,.004,.008,.008]

second = [.443,.453,.437,.346,.428,.600,.415,.280,.106,.091,.088,.054,.104]
secondError = [.026,.029,.027,.031,.032,.027,.056,.032,.029,.002,.003,.006,.010]


third = [.370,.340,.425,.420,.426,.444,.430,.316,.106,.086,.080,.073,.082]
thirdError = [ .011,.012,.012,.013,.014,.018,.013,.013,.011,.001,.001,.003,.004]

ax.errorbar(a, b, yerr=c, fmt="+", label='Eta: 0.0 - 0.5',color='black',xerr=xErrorWidth)
ax.errorbar(a, second, yerr=secondError, fmt="+", label = 'Eta: 0.5 - 1.0',color='blue',xerr=xErrorWidth)
ax.errorbar(a, third, yerr=thirdError, fmt="+", label = 'Eta: 1.0 - 2.4',color='red',xerr=xErrorWidth)
plt.ylim([0,1])
plt.xlim([30,400])
plt.ylabel('fake rate')
plt.xlabel('lepton $p_T$ [GeV]')
plt.title('electron fake rate: 2017')
plt.yticks(np.arange(0, 1.1, .1))  
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()

a = [40,55,65,75,85,95,105,115,125,155,215,275,350]
b = [.488,.557,.493,.399,.553,.616,.488,.455,.103,.091,.081,.051,.045]
 
c = [.025,.028,.028,.027,.025,.029,.035,.026,.004,.002,.002,.003,.004]

second = [.408,.437,.445,.443,.437,.521,.539,.420,.111,.089,.076,.054,.048]
secondError = [.023,.024,.026,.025,.027,.025,.027,.024,.004,.002,.002,.003,.004]


third = [.351,.356,.370,.396,.396,.421,.393,.309,.113,.082,.060,.044,.050]
thirdError = [.009,.010,.010,.011,.011,.011,.011,.009,.002,.001,.001,.001,.002 ]

ax.errorbar(a, b, yerr=c, fmt="+", label='Eta: 0.0 - 0.5',color='black',xerr=xErrorWidth)
ax.errorbar(a, second, yerr=secondError, fmt="+", label = 'Eta: 0.5 - 1.0',color='blue',xerr=xErrorWidth)
ax.errorbar(a, third, yerr=thirdError, fmt="+", label = 'Eta: 1.0 - 2.4',color='red',xerr=xErrorWidth)
plt.ylim([0,1])
plt.xlim([30,400])
plt.ylabel('fake rate')
plt.xlabel('lepton $p_T$ [GeV]')
plt.title('electron fake rate: 2018')
plt.yticks(np.arange(0, 1.1, .1))  
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()

a = [40,55,65,75,85,95,105,115,125,155,215,275,350]
b = [.675,.571,.527,.472,.619,.490,.661,.289,.078,.085,.094,.096,.099]
c = [.058,.048,.049,.058,.057,.067,.053,.041,.006,.003,.005,.013,.016]

second = [.391,.588,.483,.429,.449,.491,.403,.359,.010,.085,.099,.108,.101]
secondError = [.044,.048,.047,.046,.045,.044,.056,.039,.006,.003,.004,.012,.014]

third = [.355,.361,.316,.431,.371,.392,.368,.235,.082,.060,.060,.057,.071]
thirdError = [ .016,.018,.017,.018,.018,.018,.017,.012,.002,.001,.001,.003,.005]

ax.errorbar(a, b, yerr=c, fmt="+", label='Eta: 0.0 - 0.5',color='black',xerr=xErrorWidth)
ax.errorbar(a, second, yerr=secondError, fmt="+", label = 'Eta: 0.5 - 1.0',color='blue',xerr=xErrorWidth)
ax.errorbar(a, third, yerr=thirdError, fmt="+", label = 'Eta: 1.0 - 2.4',color='red',xerr=xErrorWidth)
plt.ylim([0,1])
plt.xlim([30,400])
plt.ylabel('fake rate')
plt.xlabel('lepton $p_T$ [GeV]')
plt.title('electron fake rate: 2016')
plt.yticks(np.arange(0, 1.1, .1))  
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()

a = [40,55,65,75,85,95,105,115,125,155,215,275,350]
b = [.552,.747,.603,.648,.542,.329,.469,.334,.075,.066,.045,.068,.081]
c = [.047,.039,.044,.047,.043,.046,.054,.032,.005,.003,.003,.009,.012]

second = [.505,.566,.455,.560,.345,.412,.465,.203,.083,.068,.057,.043,.022]
secondError = [.037,.042,.044,.040,.044,.040,.040,.026,.005,.002,.003,.007,.006]

third = [.309,.322,.308,.307,.332,.309,.285,.196,.066,.052,.049,.047,.063]
thirdError = [ .012,.014,.013,.013,.013,.013,.013,.008,.002,.001,.001,.003,.004]

ax.errorbar(a, b, yerr=c, fmt="+", label='Eta: 0.0 - 0.5',color='black',xerr=xErrorWidth)
ax.errorbar(a, second, yerr=secondError, fmt="+", label = 'Eta: 0.5 - 1.0',color='blue',xerr=xErrorWidth)
ax.errorbar(a, third, yerr=thirdError, fmt="+", label = 'Eta: 1.0 - 2.4',color='red',xerr=xErrorWidth)
plt.ylim([0,1])
plt.xlim([30,400])
plt.ylabel('fake rate')
plt.xlabel('lepton $p_T$ [GeV]')
plt.title('electron fake rate: 2016APV')

plt.yticks(np.arange(0, 1.1, .1))  
ax.legend()
plt.show()
