# %%
import glob
import os
import json
import pickle
import yaml

import math
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import pyarrow.parquet as pq
from sklearn.metrics import auc, roc_curve
from scipy.special import softmax

import hist as hist2
import matplotlib.pyplot as plt
import mplhep as hep

plt.style.use(hep.style.CMS)

import utils_farouk2 as utils
plt.rcParams.update({"font.size": 20})

# %%
binDenominator = [37120, 340067, 14291, 14006, 13085, 11867, 56192,6355 ]
binErrorDenominator = np.sqrt(binDenominator)

denominatorDxDividedByX = binErrorDenominator/binDenominator
denominatorDxDividedByX

binNumerator = [2526, 5599, 7314, 7220 , 6641  , 6069, 33548 ,4590 ]
binErrorNumerator = np.sqrt(binNumerator)
numeratorDxDividedByX = binErrorNumerator/binNumerator
numeratorDxDividedByX


#Need Square Root of Sum of Squares
first = denominatorDxDividedByX*denominatorDxDividedByX
second = numeratorDxDividedByX*numeratorDxDividedByX

sumError = first+second
sumError
errorBar = np.sqrt(sumError)
errorBar

ratio = np.array(binNumerator)/np.array(binDenominator)
ratio
errorBarFinal = errorBar*ratio
errorBarFinal
# Out:
# array([0.06804957, 0.0164644 , 0.51179064, 0.51549336, 0.5075277 ,
#        0.51141822, 0.59702449, 0.72226593])

# %%
#for electron
binDenominator = [7553, 6532, 6131, 5594,5275,4897,273548 ,131609  ]
binErrorDenominator = np.sqrt(binDenominator)

denominatorDxDividedByX = binErrorDenominator/binDenominator
denominatorDxDividedByX

binNumerator = [1040,2255,3101,3157,2886,2710,16080,3318 ]
binErrorNumerator = np.sqrt(binNumerator)
numeratorDxDividedByX = binErrorNumerator/binNumerator
numeratorDxDividedByX


#Need Square Root of Sum of Squares
first = denominatorDxDividedByX*denominatorDxDividedByX
second = numeratorDxDividedByX*numeratorDxDividedByX

sumError = first+second
sumError
errorBar = np.sqrt(sumError)
errorBar

ratio = np.array(binNumerator)/np.array(binDenominator)
ratio
errorBarFinal =  errorBar*ratio
errorBarFinal
# Out:
# array([0.00455418, 0.00843188, 0.01114556, 0.01256268, 0.01266736,
#        0.0132494 , 0.00047699, 0.00044316])

# %%
electrons
            lepton_dz  lepton_dxy  lepton_sip3d  fj_msoftdrop    lep_pt  \
lep_pt                                                                    
(40, 50]     0.187597    0.187597      0.187597      0.187597  0.187597   
(50, 60]     0.459764    0.459764      0.459764      0.459764  0.459764   
(60, 70]     0.635006    0.635006      0.635006      0.635006  0.635006   
(70, 80]     0.662750    0.662750      0.662750      0.662750  0.662750   
(80, 90]     0.651142    0.651142      0.651142      0.651142  0.651142   
(90, 100]    0.641950    0.641950      0.641950      0.641950  0.641950   
(100, 200]   0.061860    0.061860      0.061860      0.061860  0.061860   
(200, 500]   0.028363    0.028363      0.028363      0.028363  0.028363

# %%
bin1 = [40,50,60,70,80,90,150,200]
bin2 = [ 0.187597 ,0.459764 ,0.635006,0.662750, 0.651142  ,0.641950,0.061860, 0.028363]


binErrors = [0.00455418, 0.00843188, 0.01114556, 0.01256268, 0.01266736,
       0.0132494 , 0.00047699, 0.00044316]
#plt.scatter(bin1, bin2)

plt.errorbar(bin1, bin2, yerr=binErrors, fmt="o")
plt.xlabel('electron $p_T$ (GeV)')
plt.ylabel('fake rate')
plt.xticks([40,50,60,70,80,90,100,200])
plt.title('fake rate for electron channel')
# Out:
# Text(0.5, 1.0, 'fake rate for electron channel')

# %%
bin1 = [40,50,60,70,80,90,150,200]
bin2 = [0.068050, 0.016464, 0.511791, 0.515493, 0.507528, 0.511418  , 0.597024  , 0.722266 ]

#binErrors = [0.15838923, 0.12279687, 0.14162613, 0.14219181, 0.1449591 ,
 #      0.14837813, 0.09837794, 0.16524051]

binErrors = [0.00139928, 0.00022184, 0.00735802, 0.00746847, 0.00764673,       0.00807068, 0.00411922, 0.01399075]

#plt.scatter(bin1, bin2)

plt.errorbar(bin1, bin2, yerr=binErrors, fmt="o")
plt.xlabel('muon $p_T$ (GeV)')
plt.ylabel('fake rate')
plt.xticks([40,50,60,70,80,90,100,200])
plt.title('fake rate for muon channel')
# Out:
# Text(0.5, 1.0, 'fake rate for muon channel')

# %%
#bin 1 for muon, first eta bin only
binDenominator = [2164,29705,723,739, 714,652,3619,720]
binErrorDenominator = np.sqrt(binDenominator)
denominatorDxDividedByX = binErrorDenominator/binDenominator
denominatorDxDividedByX
binNumerator = [ 120,272,383,401,405,360,2190,1380]
binErrorNumerator = np.sqrt(binNumerator)
numeratorDxDividedByX = binErrorNumerator/binNumerator
numeratorDxDividedByX

#Need Squart Root of Sum of Squares
first = denominatorDxDividedByX
second = numeratorDxDividedByX

sumError = first+second
sumError
errorBar = np.sqrt(sumError)
errorBar

ratio = np.array(binNumerator)/np.array(binDenominator)
ratio
# Out:
# array([0.05545287, 0.00915671, 0.52973721, 0.54262517, 0.56722689,
#        0.55214724, 0.60513954, 1.91666667])

# %%
                       lepton_dz  lepton_dxy  lepton_sip3d  fj_msoftdrop  \
lep_pt     lep_eta                                                         
(40, 50]   (0.0, 0.5]       2164        2164          2164          2164   
           (0.5, 1.0]       2194        2194          2194          2194   
           (1.0, 1.5]       2982        2982          2982          2982   
           (1.5, 2.0]       1766        1766          1766          1766   
(50, 60]   (0.0, 0.5]      29705       29705         29705         29705   
           (0.5, 1.0]      26302       26302         26302         26302   
           (1.0, 1.5]      20071       20071         20071         20071   
           (1.5, 2.0]      11617       11617         11617         11617   
(60, 70]   (0.0, 0.5]        723         723           723           723   
           (0.5, 1.0]        703         703           703           703   
           (1.0, 1.5]        764         764           764           764   
           (1.5, 2.0]        608         608           608           608   
(70, 80]   (0.0, 0.5]        739         739           739           739   
           (0.5, 1.0]        667         667           667           667   
           (1.0, 1.5]        785         785           785           785   
           (1.5, 2.0]        612         612           612           612   
(80, 90]   (0.0, 0.5]        714         714           714           714   
           (0.5, 1.0]        673         673           673           673   
           (1.0, 1.5]        749         749           749           749   
           (1.5, 2.0]        569         569           569           569   
(90, 100]  (0.0, 0.5]        652         652           652           652   
           (0.5, 1.0]        624         624           624           624   
           (1.0, 1.5]        702         702           702           702   
           (1.5, 2.0]        508         508           508           508   
(100, 200] (0.0, 0.5]       3619        3619          3619          3619   
           (0.5, 1.0]       3448        3448          3448          3448   
           (1.0, 1.5]       3390        3390          3390          3390   
           (1.5, 2.0]       2354        2354          2354          2354   
(200, 500] (0.0, 0.5]        720         720           720           720   
           (0.5, 1.0]        624         624           624           624   
           (1.0, 1.5]        526         526           526           526   
           (1.5, 2.0]        308         308           308           308   

lep_pt     lep_eta                                                         
(40, 50]   (0.0, 0.5]        120         120           120           120   
           (0.5, 1.0]        141         141           141           141   
           (1.0, 1.5]        106         106           106           106   
           (1.5, 2.0]        104         104           104           104   
(50, 60]   (0.0, 0.5]        272         272           272           272   
           (0.5, 1.0]        285         285           285           285   
           (1.0, 1.5]        256         256           256           256   
           (1.5, 2.0]        220         220           220           220   
(60, 70]   (0.0, 0.5]        383         383           383           383   
           (0.5, 1.0]        359         359           359           359   
           (1.0, 1.5]        353         353           353           353   
           (1.5, 2.0]        278         278           278           278   
(70, 80]   (0.0, 0.5]        401         401           401           401   
           (0.5, 1.0]        368         368           368           368   
           (1.0, 1.5]        362         362           362           362   
           (1.5, 2.0]        295         295           295           295   
(80, 90]   (0.0, 0.5]        405         405           405           405   
           (0.5, 1.0]        318         318           318           318   
           (1.0, 1.5]        370         370           370           370   
           (1.5, 2.0]        243         243           243           243   
(90, 100]  (0.0, 0.5]        360         360           360           360   
           (0.5, 1.0]        328         328           328           328   
           (1.0, 1.5]        340         340           340           340   
           (1.5, 2.0]        241         241           241           241   
(100, 200] (0.0, 0.5]       2190        2190          2190          2190   
           (0.5, 1.0]       2016        2016          2016          2016   
           (1.0, 1.5]       1921        1921          1921          1921   
           (1.5, 2.0]       1380        1380          1380          1380   
(200, 500] (0.0, 0.5]        514         514           514           514   
           (0.5, 1.0]        435         435           435           435   
           (1.0, 1.5]        384         384           384           384   
           (1.5, 2.0]        236         236           236           236

# %%
bin1 = [40,50,60,70,80,90,150,200]
bin2 = [0.05545287, 0.00915671, 0.52973721, 0.54262517, 0.56722689,
       0.55214724, 0.60513954, 1.91666667]

binErrors = [0.33583295, 0.25775183, 0.29713299, 0.29448805, 0.29515159,
       0.30309677, 0.19491421, 0.25335133]

plt.errorbar(bin1, bin2, yerr=binErrors, fmt="o")
plt.xlabel('muon $p_T$ (GeV)')
plt.ylabel('fake rate')
#plt.xticks([0,0.5,1,1.5,2])
plt.title('fake rate for muon channel')
# Out:
# Text(0.5, 1.0, 'fake rate for muon channel')
