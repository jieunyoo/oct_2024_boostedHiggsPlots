# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = [[0.01892846, 0.02284451, 0.02558747, 0.03184713],
       [0.02190434, 0.02517408, 0.02494331, 0.02849003],
       [0.02601969, 0.0329053 , 0.02979275, 0.02112676],
       [0.03222094, 0.02773723, 0.02985075, 0.02545455],
       [0.02734375, 0.03863636, 0.02867384, 0.04827586],
       [0.02346041, 0.03669725, 0.02777778, 0.02352941],
       [0.03862661, 0.01265823, 0.04651163, 0.046875  ],
       [0.01948052, 0.03333333, 0.03614458, 0.        ],
       [0.00        , 0.05194805, 0.00        , 0.04166667],
       [0.05633803, 0.00        , 0.00        , 0.1       ],
       [0.02173913, 0.02857143, 0.        , 0.00        ],
       [0.04166667, 0.00000        , 0.05555556, 0.00        ],
       [0.07407407, 0.00000        , 0.00        , 0.00        ],
       [0.01652893, 0.025     , 0.04761905, 0.13333333]]
# plotting the heatmap 
x_axis_labels = ['0-0.625','0.625-1.25','1.25-1.875','1.875-2.5' ]# labels for x-axis

y_axis_labels = ['40-60', '60-80', '80-100','100-120','120-140', '140-160', '160-180', '180-200',
                '200-220', '220-240','240-260','260-280','280-300','300-1000']#

hm = sn.heatmap(data = data, cmap = 'viridis',annot=True,xticklabels=x_axis_labels, yticklabels=y_axis_labels,
                fmt=".2f") 

plt.title('b-tag eff. map: 2018: Flavor 4', fontsize = 20) # title with fontsize 20
plt.xlabel('abs(eta)', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('$p_T$ [GeV]', fontsize = 15) # y-axis label with fontsize 15

plt.savefig('2018_4.png')
plt.show()

# %%
data = [[0.00074524, 0.0008429 , 0.00061647, 0.00081577],
       [0.00100411, 0.00116525, 0.00087886, 0.        ],
       [0.00060689, 0.00214362, 0.00120656, 0.00124585],
       [0.00179028, 0.00181873, 0.00124069, 0.00138313],
       [0.00081169, 0.00151286, 0.00194426, 0.00228311],
       [0.00069589, 0.        , 0.00228571, 0.0017301 ],
       [0.        , 0.00244798, 0.00172712, 0.00529101],
       [0.00172117, 0.00369686, 0.        , 0.        ],
       [0.00246305, 0.        , 0.        , 0.        ],
       [0.        , 0.        , 0.        , 0.        ],
       [0.        , 0.01041667, 0.        , 0.        ],
       [0.        , 0.00694444, 0.        , 0.        ],
       [0.00813008, 0.        , 0.        , 0.        ],
       [0.        , 0.        , 0.00307692, 0.        ]]
# plotting the heatmap 
x_axis_labels = ['0-0.625','0.625-1.25','1.25-1.875','1.875-2.5' ]# labels for x-axis

y_axis_labels = ['40-60', '60-80', '80-100','100-120','120-140', '140-160', '160-180', '180-200',
                '200-220', '220-240','240-260','260-280','280-300','300-1000']#

hm = sn.heatmap(data = data, cmap = 'viridis',annot=True,xticklabels=x_axis_labels, yticklabels=y_axis_labels,
                fmt=".2f") 

plt.title('b-tag eff. map: 2018: Flavor 0', fontsize = 20) # title with fontsize 20
plt.xlabel('abs(eta)', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('$p_T$ [GeV]', fontsize = 15) # y-axis label with fontsize 15

plt.savefig('2018_0.png')
plt.show()

# %%
data = [[0.5965777 , 0.57812164, 0.52481203, 0.46440217],
       [0.62059019, 0.61341512, 0.53430888, 0.48812569],
       [0.6337984 , 0.62668227, 0.534645  , 0.46968869],
       [0.62373372, 0.61328005, 0.53711388, 0.44922232],
       [0.64758918, 0.60118168, 0.55590305, 0.46969697],
       [0.61962797, 0.59391635, 0.51358696, 0.49068323],
       [0.63983051, 0.5703125 , 0.50452489, 0.38650307],
       [0.61598746, 0.60165975, 0.44      , 0.45833333],
       [0.55897436, 0.5442623 , 0.39655172, 0.35483871],
       [0.52189781, 0.47150259, 0.44791667, 0.15384615],
       [0.51630435, 0.5       , 0.47222222, 0.15789474],
       [0.47413793, 0.48387097, 0.46511628, 0.45454545],
       [0.50574713, 0.44285714, 0.34482759, 0.4       ],
       [0.36363636, 0.33165829, 0.19417476, 0.15789474]]
# plotting the heatmap 
x_axis_labels = ['0-0.625','0.625-1.25','1.25-1.875','1.875-2.5' ]# labels for x-axis

y_axis_labels = ['40-60', '60-80', '80-100','100-120','120-140', '140-160', '160-180', '180-200',
                '200-220', '220-240','240-260','260-280','280-300','300-1000']#

hm = sn.heatmap(data = data, cmap = 'viridis',annot=True,xticklabels=x_axis_labels, yticklabels=y_axis_labels,
                fmt=".2f") 

plt.title('b-tag eff. map: 2018: Flavor 5', fontsize = 20) # title with fontsize 20
plt.xlabel('abs(eta)', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('$p_T$ [GeV]', fontsize = 15) # y-axis label with fontsize 15

plt.savefig('2018_5.png')
plt.show()
